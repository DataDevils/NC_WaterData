# %%
import requests
import bs4
import pandas as pd

# %%
theURL = 'https://www.pwss.enr.state.nc.us/NCDWW2/JSP/turbsummary.jsp'
payload={'tinwsys_is_number':'15263',
         'tinwsys_st_code':'NC',
         'begin_date':'',
         'end_date':'',
         'counter':'0'}

# %%
r = requests.get(theURL, payload)

# %%
dfs = pd.read_html(r.url)
len(dfs)
# Out:
# 7

# %%
dfs[0].head()
# Out:
#                                                  0                    1    \
# 0  County Map of NC  Water System Search  Public ...     County Map of NC
# 1                                   County Map of NC  Water System Search
# 2                    Water System Detail Information                  NaN
# 3                                  Water System No.:            NC0332010
# 4                                 Water System Name:      DURHAM, CITY OF
#
#                                      2    \
# 0                    Water System Search
# 1  Public Water Supply Section Home Page
# 2                                    NaN
# 3                          Federal Type:
# 4                        Federal Source:
#
#                                      3    4    \
# 0  Public Water Supply Section Home Page  NaN
# 1                                    NaN  NaN
# 2                                    NaN  NaN
# 3                                      C  NaN
# ...

# %%
r.url
# Out:
# 'https://www.pwss.enr.state.nc.us/NCDWW2/JSP/turbsummary.jsp?tinwsys_st_code=NC&counter=0&begin_date=&tinwsys_is_number=15263&end_date='
