# %% [markdown]
# ## Charlotte Water Quality Data Scraper
# ArcGIS Rest Site: https://cltwmaps.ci.charlotte.nc.us/arcgis/rest/services/Public

# %%
#imports
import requests, json, os
import pandas as pd

# %% [markdown]
# ### Functions

# %%
def getServices(baseURL):
    '''Returns a list of services at the root level'''
    params = dict(f='json') #format = json
    j = requests.get(baseURL,params).json()
    return j['services']

# %%
def getServiceInfo(baseURL,ID):
    '''Returns the MapServer URL, its name, and the max records'''
    params = dict(f='json') #format = json
    j = requests.get(baseURL,params).json()
    services = j['services']
    service = services[ID]
    serviceURL = baseURL[:-6] + service['name'] + "/" + service['type']
    return (serviceURL,service['name'])

# %%
def getLayers(serviceURL):
    '''Returns a list of layers contained in the provided map service'''
    j = requests.get(serviceURL+"?f=pjson").json()
    layers = j['layers']
    return layers

# %%
def getTables(serviceURL):
    '''Returns a list of layers contained in the provided map service'''
    j = requests.get(serviceURL+"?f=pjson").json()
    tables = j['tables']
    return tables

# %%
def getRecordCount(serviceURL, layerID):
    '''Returns the number of records in the supplied layer'''
    layerURL = "{}/{}/query".format(serviceURL,layerID)
    params = dict(f='json',
                  where='OBJECTID >= 0',
                  returnCountOnly='true')
    j = requests.get(layerURL,params).json()
    return j['count']

# %%
def getFieldList(serviceURL,layerID):
    '''Returns a list of fields for the supplied layer'''
    layerURL = "{}/{}?f=json".format(serviceURL,layerID)            
    j = requests.get(layerURL).json()
    return j['fields']

# %%
def tableToCSV(serviceURL,table,outFolder,overwrite=False):
    '''Saves the data in a table to a CSV file'''
    
    #Get table properties
    tableID = table['id']
    tableName = table['name']
    
    #Set the output name, see if it already exists
    outFN = "{}/{}.csv".format(outFolder,tableName)
    if (os.path.exists(outFN)):
        print("   {} already processed".format(tableName),end=", ")
        if overwrite == False:
            print("Skipping...")
            return
        else:
            print("Overwriting...")
    
    #Get the table query URL
    qURL = "{}/{}/query".format(serviceURL,tableID)

    #Get the number of records
    recordCount = getRecordCount(serviceURL,tableID)
    if recordCount == 0:
        print("\n  No records for {}".format(tableName))
        return
    print("\n  Fetching {} records for {}".format(recordCount,tableName),end=":")

    #Query data 1000 records at a time and add them to a dataframe
    offset = 0
    while offset < recordCount:
        #Status
        print(min(recordCount,offset+1000),end=" ")
        #Get the next 1000 records
        qParams = dict(f='pjson',where='OBJECTID>0',resultOffset=offset,outFields='*')
        j = requests.get(qURL,qParams).json()

        #Get attributes of the selected table
        fields = j['fields']
        features = j['features']

        #Create a dataframe from the first record (transposed)
        if offset == 0: #It's the first record in the dataset
            df = pd.DataFrame(features[0]).T
            startIdx = 1  #We need to skip the first record now...
        else:
            startIdx = 0  #Start at the first record

        #Add the remaining records (transposed)
        for f in features[startIdx:]:
            df = df.append(pd.DataFrame(f).T)

        #Get next set 
        offset+=1000

    #Convert index and date fields (if present)
    for f in fields:
        #Set the OID field as the index
        if f['type'] == 'esriFieldTypeOID':
            df.set_index(f['name'],inplace=True)
        #Convert dates
        if f['type'] == 'esriFieldTypeDate':
            name = (f['name'])
            df[name] = pd.to_datetime(df[name],unit='ms')

    #Write to a file
    outFN = "{}/{}.csv".format(outFolder,table['name'])
    print("\n  {} records saved to {}".format(len(df),outFN))
    df.to_csv(outFN)

# %%
def layerToCSV(serviceName,layer,outFolder,overwrite=False):
    '''Saves the data in the REST layer to a CSV (Point FCs only)'''
    #Get table properties
    layerID = layer['id']
    layerName = layer['name']
    
    #Set the output name, see if it already exists
    outFN = "{}/{}.csv".format(outFolder,layerName)
    if (os.path.exists(outFN)):
        print("   {} already processed".format(layerName),end=", ")
        if overwrite == False:
            print("Skipping...")
            return
        else:
            print("Overwriting...")
    
    #Get the table query URL
    qURL = "{}/{}/query".format(serviceURL,layerID)
    
    #Skip group layers that point to sub layers
    if layer['subLayerIds'] != None:
        print("\n  {} is a group layer...".format(layerName))
        return 

    #Get the number of records (see if it's < 1000)
    recordCount = getRecordCount(serviceURL,layerID)
    if recordCount == 0:
        print("\n  No records for {}".format(layerName))
        return
    print("\n  Fetching {} records for {}".format(recordCount,layerName),end=":")

    #Loop through 1000 records at a time
    offset = 0
    while offset < recordCount:
        #Get the next 1000 records
        qParams = dict(f='pjson',where='OBJECTID>0',resultOffset=offset,outFields='*',outSR='4326',datumTransformation='1188')
        print(min(recordCount,offset+1000),end=" ")
        
        #Retrieve data as a JSON object
        j = requests.get(qURL,qParams).json()

        #Get attributes of the selected table
        fields = j['fields']
        features = j['features']

        #Create a dataframe from the first record (transposed)
        if offset == 0: #It's the first record in the dataset
            feature = features[0]
            df = pd.DataFrame.from_dict(feature['attributes'],orient='index').T
            #Get and add the coordinates
            if 'geometry' in feature.keys():
                df['x']=feature['geometry']['x']
                df['y']=feature['geometry']['y']
            startIdx = 1
        else:
            startIdx = 0

        #Add the remaining records (transposed)
        for feature in features[startIdx:]:
            df2 = pd.DataFrame.from_dict(feature['attributes'],orient='index').T
            if 'geometry' in feature.keys():
                df2['x']=feature['geometry']['x']
                df2['y']=feature['geometry']['y']
            df = df.append(df2)

        #Get next set 
        offset+=1000

    #Convert fields
    for f in fields:
        #Set the OID field as the index
        if f['type'] == 'esriFieldTypeOID':
            df.set_index(f['name'],inplace=True)
        #Convert dates
        if f['type'] == 'esriFieldTypeDate':
            name = (f['name'])
            df[name] = pd.to_datetime(df[name],unit='ms')

    #Write to a file
    outFN = "{}/{}.csv".format(outFolder,layer['name'])
    print("\n  {} records saved to {}".format(len(df),outFN))
    df.to_csv(outFN)

# %% [markdown]
# ### Main
# The Charlotte REST server lists a number of Map Services with one or more layer

# %%
#Scrape all data (Tables and Layers)
baseURL = 'https://cltwmaps.ci.charlotte.nc.us/arcgis/rest/services/Public'

for serviceIndex in (1,2,3,4,5,6,7,8,9,13):

    #Get the map service and its name
    serviceURL,serviceName = getServiceInfo(baseURL,serviceIndex)
    print("\n-------\nPROCESSING {}".format(serviceName))
    
    #Create a folder to hold the results
    outFolder = '../Data/Charlotte/'+serviceName[7:]
    if not os.path.exists(outFolder): os.mkdir(outFolder)

    #Get a list of tables and layers
    tables = getTables(serviceURL)
    layers = getLayers(serviceURL)
    
    #Loop through tables hosted in the service and save to CSV
    for i, table in enumerate(tables):
        tableToCSV(serviceURL,table,outFolder)
        
    #Loop through the layers hosted in the service and save to CSV
    for i, layer in enumerate(layers):
        layerToCSV(serviceURL,layer,outFolder,overwrite=True)
    
print("Finished!")
# Out:
# -------
# PROCESSING Public/CLTW_DrinkingWaterCHLORINE2
#    Free Chlorine Results (2015) already processed, Skipping...
#    Free Chlorine already processed, Overwriting...
#
#   Fetching 508 records for Free Chlorine:508
#   508 records saved to ../Data/Charlotte/CLTW_DrinkingWaterCHLORINE2/Free Chlorine.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterDBP
#    Total Trihalomethanes Results (2015) already processed, Skipping...
#    Haloacetic Acids Results (2015) already processed, Skipping...
#    Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 24 records for Total Trihalomethanes:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterDBP/Total Trihalomethanes.csv
#    Haloacetic Acids already processed, Overwriting...
#
#   Fetching 24 records for Haloacetic Acids:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterDBP/Haloacetic Acids.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterINORGANIC2
#    Fluoride Results (2015) already processed, Skipping...
#    Arsenic Results (2015) already processed, Skipping...
#    Arsenic already processed, Overwriting...
#
#   Fetching 7 records for Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_DrinkingWaterINORGANIC2/Arsenic.csv
#    Fluoride already processed, Overwriting...
#
#   Fetching 223 records for Fluoride:223
#   223 records saved to ../Data/Charlotte/CLTW_DrinkingWaterINORGANIC2/Fluoride.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterLEAD5
#    Lead 2016 Results (Distribution System) already processed, Skipping...
#    Lead 2016 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2013 Results (Lead & Copper Rule) already processed, Skipping...
#    Community Outreach Lead Sample Locations (2016) already processed, Overwriting...
#
#   Fetching 106 records for Community Outreach Lead Sample Locations (2016):106
#   106 records saved to ../Data/Charlotte/CLTW_DrinkingWaterLEAD5/Community Outreach Lead Sample Locations (2016).csv
#    Lead & Copper Rule Sample Locations (2016) already processed, Overwriting...
#
#   Fetching 56 records for Lead & Copper Rule Sample Locations (2016):56
#   56 records saved to ../Data/Charlotte/CLTW_DrinkingWaterLEAD5/Lead & Copper Rule Sample Locations (2016).csv
#    Lead & Copper Rule Sample Locations (2013) already processed, Overwriting...
#
#   Fetching 51 records for Lead & Copper Rule Sample Locations (2013):51
#   51 records saved to ../Data/Charlotte/CLTW_DrinkingWaterLEAD5/Lead & Copper Rule Sample Locations (2013).csv
#    Distribution System Sample Locations (2016) already processed, Overwriting...
#
#   Fetching 203 records for Distribution System Sample Locations (2016):203
#   203 records saved to ../Data/Charlotte/CLTW_DrinkingWaterLEAD5/Distribution System Sample Locations (2016).csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterMICRO
#    E. coli Results already processed, Skipping...
#    Total Coliform Results already processed, Skipping...
#    Total Coliform already processed, Overwriting...
#
#   Fetching 506 records for Total Coliform:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterMICRO/Total Coliform.csv
#    E. coli already processed, Overwriting...
#
#   Fetching 506 records for E. coli:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterMICRO/E. coli.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterORGANICS
#    Organic Chemicals Results (2015) already processed, Skipping...
#    Organic Chemicals already processed, Overwriting...
#
#   Fetching 5 records for Organic Chemicals:5
#   5 records saved to ../Data/Charlotte/CLTW_DrinkingWaterORGANICS/Organic Chemicals.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterQuality_2017
#    Organic Chemicals Results (2015) already processed, Skipping...
#    Free Chlorine Results (2015) already processed, Skipping...
#    Arsenic Results (2015) already processed, Skipping...
#    Iron Results (2015) already processed, Skipping...
#    Total Trihalomethanes Results (2015) already processed, Skipping...
#    Haloacetic Acids Results (2015) already processed, Skipping...
#    Fluoride Results (2015) already processed, Skipping...
#    Total Coliform Results (2015) already processed, Skipping...
#    E.coli Results (2015) already processed, Skipping...
#    Arsenic Results (2016) already processed, Skipping...
#    E.coli Results (2016) already processed, Skipping...
#    Fluoride Results (2016) already processed, Skipping...
#    Free Chlorine Results (2016) already processed, Skipping...
#    Iron Results (2016) already processed, Skipping...
#    Organics Results (2016) already processed, Skipping...
#    Total Trihalomethanes Results (2016) already processed, Skipping...
#    Total Coliform Results (2016) already processed, Skipping...
#    Haloacetic Acids Results (2016) already processed, Skipping...
#    Arsenic Results (2017) already processed, Skipping...
#    E.coli Results (2017) already processed, Skipping...
#    Fluoride Results (2017) already processed, Skipping...
#    Free Chlorine Results (2017) already processed, Skipping...
#    Iron Results (2017) already processed, Skipping...
#    Organics Results (2017) already processed, Skipping...
#    Total Trihalomethanes Results (2017) already processed, Skipping...
#    Total Coliform Results (2017) already processed, Skipping...
#    Haloacetic Acids Results (2017) already processed, Skipping...
#    Lead 2017 Results (Distribution System) already processed, Skipping...
#    Lead 2016 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2013 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2016 Results (Distribution System) already processed, Skipping...
#
#   Microorganisms is a group layer...
#
#   Total Coliform is a group layer...
#    2017 Total Coliform already processed, Overwriting...
#
#   Fetching 397 records for 2017 Total Coliform:397
#   397 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Total Coliform.csv
#    2016 Total Coliform already processed, Overwriting...
#
#   Fetching 489 records for 2016 Total Coliform:489
#   489 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Total Coliform.csv
#    2015 Total Coliform already processed, Overwriting...
#
#   Fetching 506 records for 2015 Total Coliform:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Total Coliform.csv
#
#   E. coli is a group layer...
#    2017 E. coli already processed, Overwriting...
#
#   Fetching 397 records for 2017 E. coli:397
#   397 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 E. coli.csv
#    2016 E. coli already processed, Overwriting...
#
#   Fetching 489 records for 2016 E. coli:489
#   489 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 E. coli.csv
#    2015 E. coli already processed, Overwriting...
#
#   Fetching 506 records for 2015 E. coli:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 E. coli.csv
#
#   Disinfection Byproducts is a group layer...
#
#   Total Haloacetic Acids  is a group layer...
#    2017 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Haloacetic Acids:12
#   12 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Total Haloacetic Acids.csv
#    2016 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Haloacetic Acids:13
#   13 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Total Haloacetic Acids.csv
#    2015 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Haloacetic Acids:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Total Haloacetic Acids.csv
#
#   Total Trihalomethanes is a group layer...
#    2017 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Trihalomethanes:12
#   12 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Total Trihalomethanes.csv
#    2016 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Trihalomethanes:13
#   13 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Total Trihalomethanes.csv
#    2015 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Trihalomethanes:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Total Trihalomethanes.csv
#
#   Lead and Copper is a group layer...
#
#   Distribution Sampling is a group layer...
#    2017 Distribution System Samples already processed, Overwriting...
#
#   Fetching 30 records for 2017 Distribution System Samples:30
#   30 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Distribution System Samples.csv
#    2016 Distribution System Samples  already processed, Overwriting...
#
#   Fetching 203 records for 2016 Distribution System Samples :203
#   203 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Distribution System Samples .csv
#
#   Lead and Copper Rule Sampling is a group layer...
#    2016 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 56 records for 2016 Lead & Copper Rule Samples:56
#   56 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Lead & Copper Rule Samples.csv
#    2013 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 51 records for 2013 Lead & Copper Rule Samples:51
#   51 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2013 Lead & Copper Rule Samples.csv
#
#   Inorganic Chemicals is a group layer...
#
#   Arsenic is a group layer...
#    2017 Arsenic already processed, Overwriting...
#
#   Fetching 3 records for 2017 Arsenic:3
#   3 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Arsenic.csv
#    2016 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2016 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Arsenic.csv
#    2015 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2015 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Arsenic.csv
#
#   Fluoride is a group layer...
#    2017 Fluoride already processed, Overwriting...
#
#   Fetching 167 records for 2017 Fluoride:167
#   167 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Fluoride.csv
#    2016 Fluoride already processed, Overwriting...
#
#   Fetching 242 records for 2016 Fluoride:242
#   242 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Fluoride.csv
#    2015 Fluoride already processed, Overwriting...
#
#   Fetching 223 records for 2015 Fluoride:223
#   223 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Fluoride.csv
#
#   Organic Chemicals is a group layer...
#    2017 Organic Chemicals already processed, Overwriting...
#
#   Fetching 16 records for 2017 Organic Chemicals:16
#   16 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Organic Chemicals.csv
#    2016 Organic Chemicals already processed, Overwriting...
#
#   Fetching 21 records for 2016 Organic Chemicals:21
#   21 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Organic Chemicals.csv
#    2015 Organic Chemicals already processed, Overwriting...
#
#   Fetching 5 records for 2015 Organic Chemicals:5
#   5 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Organic Chemicals.csv
#
#   Disinfectants is a group layer...
#
#   Free Chlorine is a group layer...
#    2017 Free Chlorine already processed, Overwriting...
#
#   Fetching 400 records for 2017 Free Chlorine:400
#   400 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Free Chlorine.csv
#    2016 Free Chlorine already processed, Overwriting...
#
#   Fetching 483 records for 2016 Free Chlorine:483
#   483 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Free Chlorine.csv
#    2015 Free Chlorine already processed, Overwriting...
#
#   Fetching 508 records for 2015 Free Chlorine:508
#   508 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015 Free Chlorine.csv
#
#   Secondary Drinking Water Standards is a group layer...
#
#   Iron is a group layer...
#    2017 Iron already processed, Overwriting...
#
#   Fetching 3 records for 2017 Iron:3
#   3 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2017 Iron.csv
#    2016 Iron already processed, Overwriting...
#
#   Fetching 14 records for 2016 Iron:14
#   14 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2016 Iron.csv
#    2015Iron already processed, Overwriting...
#
#   Fetching 6 records for 2015Iron:6
#   6 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQuality_2017/2015Iron.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterQualityReport
#    Organic Chemicals Results (2015) already processed, Skipping...
#    Free Chlorine Results (2015) already processed, Skipping...
#    Arsenic Results (2015) already processed, Skipping...
#    Iron Results (2015) already processed, Skipping...
#    Total Trihalomethanes Results (2015) already processed, Skipping...
#    Haloacetic Acids Results (2015) already processed, Skipping...
#    Fluoride Results (2015) already processed, Skipping...
#    Total Coliform Results (2015) already processed, Skipping...
#    E.coli Results (2015) already processed, Skipping...
#    Arsenic Results (2016) already processed, Skipping...
#    E.coli Results (2016) already processed, Skipping...
#    Fluoride Results (2016) already processed, Skipping...
#    Free Chlorine Results (2016) already processed, Skipping...
#    Iron Results (2016) already processed, Skipping...
#    Organics Results (2016) already processed, Skipping...
#    Total Trihalomethanes Results (2016) already processed, Skipping...
#    Total Coliform Results (2016) already processed, Skipping...
#    Haloacetic Acids Results (2016) already processed, Skipping...
#    Arsenic Results (2017) already processed, Skipping...
#    E.coli Results (2017) already processed, Skipping...
#    Fluoride Results (2017) already processed, Skipping...
#    Free Chlorine Results (2017) already processed, Skipping...
#    Iron Results (2017) already processed, Skipping...
#    Organics Results (2017) already processed, Skipping...
#    Total Trihalomethanes Results (2017) already processed, Skipping...
#    Total Coliform Results (2017) already processed, Skipping...
#    Haloacetic Acids Results (2017) already processed, Skipping...
#    Lead 2017 Results (Distribution System) already processed, Skipping...
#    Lead 2016 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2013 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2016 Results (Distribution System) already processed, Skipping...
#
#   Microorganisms is a group layer...
#
#   Total Coliform is a group layer...
#    2017 Total Coliform already processed, Overwriting...
#
#   Fetching 397 records for 2017 Total Coliform:397
#   397 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Total Coliform.csv
#    2016 Total Coliform already processed, Overwriting...
#
#   Fetching 489 records for 2016 Total Coliform:489
#   489 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Total Coliform.csv
#    2015 Total Coliform already processed, Overwriting...
#
#   Fetching 506 records for 2015 Total Coliform:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Total Coliform.csv
#
#   E. coli is a group layer...
#    2017 E. coli already processed, Overwriting...
#
#   Fetching 397 records for 2017 E. coli:397
#   397 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 E. coli.csv
#    2016 E. coli already processed, Overwriting...
#
#   Fetching 489 records for 2016 E. coli:489
#   489 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 E. coli.csv
#    2015 E. coli already processed, Overwriting...
#
#   Fetching 506 records for 2015 E. coli:506
#   506 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 E. coli.csv
#
#   Disinfection Byproducts is a group layer...
#
#   Total Haloacetic Acids  is a group layer...
#    2017 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Haloacetic Acids:12
#   12 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Total Haloacetic Acids.csv
#    2016 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Haloacetic Acids:13
#   13 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Total Haloacetic Acids.csv
#    2015 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Haloacetic Acids:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Total Haloacetic Acids.csv
#
#   Total Trihalomethanes is a group layer...
#    2017 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Trihalomethanes:12
#   12 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Total Trihalomethanes.csv
#    2016 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Trihalomethanes:13
#   13 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Total Trihalomethanes.csv
#    2015 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Trihalomethanes:24
#   24 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Total Trihalomethanes.csv
#
#   Lead and Copper is a group layer...
#
#   Distribution Sampling is a group layer...
#    2017 Distribution System Samples already processed, Overwriting...
#
#   Fetching 30 records for 2017 Distribution System Samples:30
#   30 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Distribution System Samples.csv
#    2016 Distribution System Samples  already processed, Overwriting...
#
#   Fetching 203 records for 2016 Distribution System Samples :203
#   203 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Distribution System Samples .csv
#
#   Lead and Copper Rule Sampling is a group layer...
#    2016 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 56 records for 2016 Lead & Copper Rule Samples:56
#   56 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Lead & Copper Rule Samples.csv
#    2013 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 51 records for 2013 Lead & Copper Rule Samples:51
#   51 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2013 Lead & Copper Rule Samples.csv
#
#   Inorganic Chemicals is a group layer...
#
#   Arsenic is a group layer...
#    2017 Arsenic already processed, Overwriting...
#
#   Fetching 3 records for 2017 Arsenic:3
#   3 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Arsenic.csv
#    2016 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2016 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Arsenic.csv
#    2015 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2015 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Arsenic.csv
#
#   Fluoride is a group layer...
#    2017 Fluoride already processed, Overwriting...
#
#   Fetching 167 records for 2017 Fluoride:167
#   167 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Fluoride.csv
#    2016 Fluoride already processed, Overwriting...
#
#   Fetching 242 records for 2016 Fluoride:242
#   242 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Fluoride.csv
#    2015 Fluoride already processed, Overwriting...
#
#   Fetching 223 records for 2015 Fluoride:223
#   223 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Fluoride.csv
#
#   Organic Chemicals is a group layer...
#    2017 Organic Chemicals already processed, Overwriting...
#
#   Fetching 16 records for 2017 Organic Chemicals:16
#   16 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Organic Chemicals.csv
#    2016 Organic Chemicals already processed, Overwriting...
#
#   Fetching 21 records for 2016 Organic Chemicals:21
#   21 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Organic Chemicals.csv
#    2015 Organic Chemicals already processed, Overwriting...
#
#   Fetching 5 records for 2015 Organic Chemicals:5
#   5 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Organic Chemicals.csv
#
#   Disinfectants is a group layer...
#
#   Free Chlorine is a group layer...
#    2017 Free Chlorine already processed, Overwriting...
#
#   Fetching 400 records for 2017 Free Chlorine:400
#   400 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Free Chlorine.csv
#    2016 Free Chlorine already processed, Overwriting...
#
#   Fetching 483 records for 2016 Free Chlorine:483
#   483 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Free Chlorine.csv
#    2015 Free Chlorine already processed, Overwriting...
#
#   Fetching 508 records for 2015 Free Chlorine:508
#   508 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015 Free Chlorine.csv
#
#   Secondary Drinking Water Standards is a group layer...
#
#   Iron is a group layer...
#    2017 Iron already processed, Overwriting...
#
#   Fetching 3 records for 2017 Iron:3
#   3 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2017 Iron.csv
#    2016 Iron already processed, Overwriting...
#
#   Fetching 14 records for 2016 Iron:14
#   14 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2016 Iron.csv
#    2015Iron already processed, Overwriting...
#
#   Fetching 6 records for 2015Iron:6
#   6 records saved to ../Data/Charlotte/CLTW_DrinkingWaterQualityReport/2015Iron.csv
#
# -------
# PROCESSING Public/CLTW_DrinkingWaterSECONDARY
#    Iron Results (2015) already processed, Skipping...
#    Iron already processed, Overwriting...
#
#   Fetching 6 records for Iron:6
#   6 records saved to ../Data/Charlotte/CLTW_DrinkingWaterSECONDARY/Iron.csv
#
# -------
# PROCESSING Public/CLTW_WaterQualityUpdates_2018
#    Organic Chemicals Results (2015) already processed, Skipping...
#    Free Chlorine Results (2015) already processed, Skipping...
#    Arsenic Results (2015) already processed, Skipping...
#    Iron Results (2015) already processed, Skipping...
#    Total Trihalomethanes Results (2015) already processed, Skipping...
#    Haloacetic Acids Results (2015) already processed, Skipping...
#    Fluoride Results (2015) already processed, Skipping...
#    Total Coliform Results (2015) already processed, Skipping...
#    E.coli Results (2015) already processed, Skipping...
#    Arsenic Results (2016) already processed, Skipping...
#    E.coli Results (2016) already processed, Skipping...
#    Fluoride Results (2016) already processed, Skipping...
#    Free Chlorine Results (2016) already processed, Skipping...
#    Iron Results (2016) already processed, Skipping...
#    Organics Results (2016) already processed, Skipping...
#    Total Trihalomethanes Results (2016) already processed, Skipping...
#    Total Coliform Results (2016) already processed, Skipping...
#    Haloacetic Acids Results (2016) already processed, Skipping...
#    Arsenic Results (2017) already processed, Skipping...
#    E.coli Results (2017) already processed, Skipping...
#    Fluoride Results (2017) already processed, Skipping...
#    Free Chlorine Results (2017) already processed, Skipping...
#    Iron Results (2017) already processed, Skipping...
#    Organics Results (2017) already processed, Skipping...
#    Total Trihalomethanes Results (2017) already processed, Skipping...
#    Total Coliform Results (2017) already processed, Skipping...
#    Haloacetic Acids Results (2017) already processed, Skipping...
#    Lead 2017 Results (Distribution System) already processed, Skipping...
#    Lead 2016 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2013 Results (Lead & Copper Rule) already processed, Skipping...
#    Lead 2016 Results (Distribution System) already processed, Skipping...
#    Arsenic Results (2018) already processed, Skipping...
#    E.coli Results (2018) already processed, Skipping...
#    Fluoride Results (2018) already processed, Skipping...
#    Iron Results (2018) already processed, Skipping...
#
#   No records for CLTW.GIS.DWP_LCR2018Results
#
#   No records for Lead 2018 Results (Distribution System)
#    Organics Results (2018) already processed, Skipping...
#    Total Trihalomethanes Results (2018) already processed, Skipping...
#    Total Coliform Results (2018) already processed, Skipping...
#    Haloacetic Acids Results (2018) already processed, Skipping...
#    Free Chlorine Results (2018) already processed, Skipping...
#
#   Microorganisms is a group layer...
#
#   Total Coliform is a group layer...
#    2018 Total Coliform already processed, Overwriting...
#
#   Fetching 307 records for 2018 Total Coliform:307
#   307 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Total Coliform.csv
#    2017 Total Coliform already processed, Overwriting...
#
#   Fetching 397 records for 2017 Total Coliform:397
#   397 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Total Coliform.csv
#    2016 Total Coliform already processed, Overwriting...
#
#   Fetching 489 records for 2016 Total Coliform:489
#   489 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Total Coliform.csv
#    2015 Total Coliform already processed, Overwriting...
#
#   Fetching 506 records for 2015 Total Coliform:506
#   506 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Total Coliform.csv
#
#   E. coli is a group layer...
#    2018 E. coli already processed, Overwriting...
#
#   Fetching 307 records for 2018 E. coli:307
#   307 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 E. coli.csv
#    2017 E. coli already processed, Overwriting...
#
#   Fetching 397 records for 2017 E. coli:397
#   397 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 E. coli.csv
#    2016 E. coli already processed, Overwriting...
#
#   Fetching 489 records for 2016 E. coli:489
#   489 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 E. coli.csv
#    2015 E. coli already processed, Overwriting...
#
#   Fetching 506 records for 2015 E. coli:506
#   506 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 E. coli.csv
#
#   Disinfection Byproducts is a group layer...
#
#   Total Haloacetic Acids  is a group layer...
#    2018 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 12 records for 2018 Total Haloacetic Acids:12
#   12 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Total Haloacetic Acids.csv
#    2017 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Haloacetic Acids:12
#   12 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Total Haloacetic Acids.csv
#    2016 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Haloacetic Acids:13
#   13 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Total Haloacetic Acids.csv
#    2015 Total Haloacetic Acids already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Haloacetic Acids:24
#   24 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Total Haloacetic Acids.csv
#
#   Total Trihalomethanes is a group layer...
#    2018 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 12 records for 2018 Total Trihalomethanes:12
#   12 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Total Trihalomethanes.csv
#    2017 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 12 records for 2017 Total Trihalomethanes:12
#   12 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Total Trihalomethanes.csv
#    2016 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 13 records for 2016 Total Trihalomethanes:13
#   13 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Total Trihalomethanes.csv
#    2015 Total Trihalomethanes already processed, Overwriting...
#
#   Fetching 24 records for 2015 Total Trihalomethanes:24
#   24 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Total Trihalomethanes.csv
#
#   Lead and Copper is a group layer...
#
#   Distribution Sampling is a group layer...
#
#   No records for 2018 Distribution System Samples
#    2017 Distribution System Samples already processed, Overwriting...
#
#   Fetching 30 records for 2017 Distribution System Samples:30
#   30 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Distribution System Samples.csv
#    2016 Distribution System Samples  already processed, Overwriting...
#
#   Fetching 203 records for 2016 Distribution System Samples :203
#   203 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Distribution System Samples .csv
#
#   Lead and Copper Rule Sampling is a group layer...
#    2016 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 56 records for 2016 Lead & Copper Rule Samples:56
#   56 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Lead & Copper Rule Samples.csv
#    2013 Lead & Copper Rule Samples already processed, Overwriting...
#
#   Fetching 51 records for 2013 Lead & Copper Rule Samples:51
#   51 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2013 Lead & Copper Rule Samples.csv
#
#   Inorganic Chemicals is a group layer...
#
#   Arsenic is a group layer...
#    2018 Arsenic already processed, Overwriting...
#
#   Fetching 3 records for 2018 Arsenic:3
#   3 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Arsenic.csv
#    2017 Arsenic already processed, Overwriting...
#
#   Fetching 3 records for 2017 Arsenic:3
#   3 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Arsenic.csv
#    2016 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2016 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Arsenic.csv
#    2015 Arsenic already processed, Overwriting...
#
#   Fetching 7 records for 2015 Arsenic:7
#   7 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Arsenic.csv
#
#   Fluoride is a group layer...
#    2018 Fluoride already processed, Overwriting...
#
#   Fetching 107 records for 2018 Fluoride:107
#   107 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Fluoride.csv
#    2017 Fluoride already processed, Overwriting...
#
#   Fetching 167 records for 2017 Fluoride:167
#   167 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Fluoride.csv
#    2016 Fluoride already processed, Overwriting...
#
#   Fetching 242 records for 2016 Fluoride:242
#   242 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Fluoride.csv
#    2015 Fluoride already processed, Overwriting...
#
#   Fetching 223 records for 2015 Fluoride:223
#   223 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Fluoride.csv
#
#   Organic Chemicals is a group layer...
#    2018 Organic Chemicals already processed, Overwriting...
#
#   Fetching 16 records for 2018 Organic Chemicals:16
#   16 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Organic Chemicals.csv
#    2017 Organic Chemicals already processed, Overwriting...
#
#   Fetching 16 records for 2017 Organic Chemicals:16
#   16 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Organic Chemicals.csv
#    2016 Organic Chemicals already processed, Overwriting...
#
#   Fetching 21 records for 2016 Organic Chemicals:21
#   21 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Organic Chemicals.csv
#    2015 Organic Chemicals already processed, Overwriting...
#
#   Fetching 5 records for 2015 Organic Chemicals:5
#   5 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Organic Chemicals.csv
#
#   Disinfectants is a group layer...
#
#   Free Chlorine is a group layer...
#    2018 Free Chlorine already processed, Overwriting...
#
#   Fetching 308 records for 2018 Free Chlorine:308
#   308 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Free Chlorine.csv
#    2017 Free Chlorine already processed, Overwriting...
#
#   Fetching 400 records for 2017 Free Chlorine:400
#   400 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Free Chlorine.csv
#    2016 Free Chlorine already processed, Overwriting...
#
#   Fetching 483 records for 2016 Free Chlorine:483
#   483 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Free Chlorine.csv
#    2015 Free Chlorine already processed, Overwriting...
#
#   Fetching 508 records for 2015 Free Chlorine:508
#   508 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015 Free Chlorine.csv
#
#   Secondary Drinking Water Standards is a group layer...
#
#   Iron is a group layer...
#    2018 Iron already processed, Overwriting...
#
#   Fetching 3 records for 2018 Iron:3
#   3 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2018 Iron.csv
#    2017 Iron already processed, Overwriting...
#
#   Fetching 3 records for 2017 Iron:3
#   3 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2017 Iron.csv
#    2016 Iron already processed, Overwriting...
#
#   Fetching 14 records for 2016 Iron:14
#   14 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2016 Iron.csv
#    2015Iron already processed, Overwriting...
#
#   Fetching 6 records for 2015Iron:6
#   6 records saved to ../Data/Charlotte/CLTW_WaterQualityUpdates_2018/2015Iron.csv
# Finished!
