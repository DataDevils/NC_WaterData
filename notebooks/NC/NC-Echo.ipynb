# %% [markdown]
# https://echo.epa.gov/files/echodownloads/NPDES_by_state_year/

# %%
import pandas as pd

# %%
file1='NC_FY2018_NPDES_DMRS.csv'
file2='NC_FY2018_NPDES_LIMITS.csv'
file3='NPDES_EFF_VIOLATIONS.csv'
df1 = pd.read_csv('NC_FY2018_NPDES_DMRS.csv',low_memory=False)
df1.head()
# Out:
#    ACTIVITY_ID EXTERNAL_PERMIT_NMBR  VERSION_NMBR  PERM_FEATURE_ID  \
# 0   3400051777            NC0072699             2       3400031496
# 1   3400051777            NC0072699             2       3400031496
# 2   3400051777            NC0072699             2       3400031496
# 3   3400051777            NC0072699             2       3400031496
# 4   3400051777            NC0072699             2       3400031496
#
#   PERM_FEATURE_NMBR PERM_FEATURE_TYPE_CODE  LIMIT_SET_ID LIMIT_SET_DESIGNATOR  \
# 0               001                    EXO    3400076641                    M
# 1               001                    EXO    3400076641                    M
# 2               001                    EXO    3400076641                    M
# 3               001                    EXO    3400076641                    M
# 4               001                    EXO    3400076641                    M
#
#    LIMIT_SET_SCHEDULE_ID    LIMIT_ID         ...         VALUE_RECEIVED_DATE  \
# ...

# %%
df = pd.read_csv(file3,nrows=10)
df.head()
# Out:
#     NPDES_ID  VERSION_NMBR  ACTIVITY_ID  NPDES_VIOLATION_ID  \
# 0  AKG571021             0     20004038           601453094
# 1  NE0132811             2    600022394           601529168
# 2  IN0002186             0     20021138            20387024
# 3  IN0002364             0     20017092            20389149
# 4  NY0219304             0    600024465           601189749
#
#    PERM_FEATURE_NMBR  PERMIT_ACTIVITY_ID LIMIT_SET_DESIGNATOR  \
# 0                  1            20004038                    A
# 1                  1           600022394                    C
# 2                  1            20021138                    A
# 3                  1            20017092                    S
# 4                  1           600024465                    M
#
#    MONITORING_LOCATION_CODE  DMR_FORM_VALUE_ID  DMR_VALUE_NMBR  \
# 0                         1                NaN             NaN
# 1                         1                NaN             NaN
# ...

# %%
dfWW = df1[df1['EXTERNAL_PERMIT_NMBR']=='NC0023841']

# %%
dfWW.head()
# Out:
#        ACTIVITY_ID EXTERNAL_PERMIT_NMBR  VERSION_NMBR  PERM_FEATURE_ID  \
# 86790   3600003709            NC0023841             0       3600115476
# 86791   3600003709            NC0023841             0       3600001857
# 86792   3600003709            NC0023841             0       3600001857
# 86793   3600003709            NC0023841             0       3600001857
# 86794   3600003709            NC0023841             0       3600001857
#
#       PERM_FEATURE_NMBR PERM_FEATURE_TYPE_CODE  LIMIT_SET_ID  \
# 86790              01D2                    EXO    3600151829
# 86791               001                    EXO    3600001812
# 86792               001                    EXO    3600001812
# 86793               001                    EXO    3600001812
# 86794               001                    EXO    3600001812
#
#       LIMIT_SET_DESIGNATOR  LIMIT_SET_SCHEDULE_ID    LIMIT_ID  \
# 86790                    M             3600195872  3601547716
# ...
